# %% [markdown]
# <a href="https://colab.research.google.com/github/yzhou359/MakeItTalk/blob/main/quick_demo_tdlr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MakeItTalk Quick Demo (natural human face animation)
#
# ## TDLR version
#
# Remember to change to GPU runtime first!

# %% [markdown]
# ## Preparation (run only once)

# %%
print('Git clone project and install requirements...')
# !git clone https://github.com/yzhou359/MakeItTalk
# Out:
# Git clone project and install requirements...
# fatal: destination path 'MakeItTalk' already exists and is not an empty directory.

# %%
print('Git clone project and install requirements...')
import os
# %cd MakeItTalk/

# !pip install -r requirements.txt
# !pip install tensorboardX

import sys
sys.path.append('/content/MakeItTalk')

os.makedirs('examples/dump', exist_ok=True)
os.makedirs('examples/ckpt', exist_ok=True)

# !pip install gdown
print('Done!')
print('Download pre-trained models...')
# !gdown -O examples/ckpt/ckpt_autovc.pth https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x
# !gdown -O examples/ckpt/ckpt_content_branch.pth https://drive.google.com/uc?id=1r3bfEvTVl6pCNw5xwUhEglwDHjWtAqQp
# !gdown -O examples/ckpt/ckpt_speaker_branch.pth https://drive.google.com/uc?id=1rV0jkyDqPW-aDJcj7xSO6Zt1zSXqn1mu
# !gdown -O examples/ckpt/ckpt_116_i2i_comb.pth https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a
# !gdown -O examples/dump/emb.pickle https://drive.google.com/uc?id=18-0CYl5E6ungS3H4rRSHjfYvvm-WwjTI
print('Done!')
# Out:
# Git clone project and install requirements...
# C:\Users\chakr\Downloads\makeittalk\MakeItTalk\MakeItTalk
# Requirement already satisfied: ffmpeg-python in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: opencv-python in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.5.5.64)
# Requirement already satisfied: face_alignment in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: scikit-learn in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.0.2)
# Requirement already satisfied: pydub in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (0.25.1)
# Requirement already satisfied: pynormalize in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: soundfile in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: librosa in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (0.9.1)
# Requirement already satisfied: pysptk in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: pyworld in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (0.3.4)
# Requirement already satisfied: resemblyzer in c:\users\chakr\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: future in c:\users\chakr\anaconda3\lib\site-packages (from ffmpeg-python->-r requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\chakr\anaconda3\lib\site-packages (from opencv-python->-r requirements.txt (line 2)) (1.21.5)
# Requirement already satisfied: scikit-image in c:\users\chakr\anaconda3\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (0.19.2)
# Requirement already satisfied: scipy>=0.17 in c:\users\chakr\anaconda3\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: tqdm in c:\users\chakr\anaconda3\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (4.64.0)
# Requirement already satisfied: torch in c:\users\chakr\anaconda3\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (2.2.1+cu121)
# Requirement already satisfied: numba in c:\users\chakr\anaconda3\lib\site-packages (from face_alignment->-r requirements.txt (line 3)) (0.55.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\chakr\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: mutagen>=1.40.0 in c:\users\chakr\anaconda3\lib\site-packages (from pynormalize->-r requirements.txt (line 6)) (1.47.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\chakr\anaconda3\lib\site-packages (from soundfile->-r requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\chakr\anaconda3\lib\site-packages (from librosa->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\chakr\anaconda3\lib\site-packages (from librosa->-r requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\chakr\anaconda3\lib\site-packages (from librosa->-r requirements.txt (line 8)) (21.3)
# Requirement already satisfied: pooch>=1.0 in c:\users\chakr\anaconda3\lib\site-packages (from librosa->-r requirements.txt (line 8)) (1.8.1)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\chakr\anaconda3\lib\site-packages (from librosa->-r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: cython>=0.28.0 in c:\users\chakr\anaconda3\lib\site-packages (from pysptk->-r requirements.txt (line 9)) (0.29.28)
# Requirement already satisfied: typing in c:\users\chakr\anaconda3\lib\site-packages (from resemblyzer->-r requirements.txt (line 11)) (3.7.4.3)
# Requirement already satisfied: webrtcvad>=2.0.10 in c:\users\chakr\anaconda3\lib\site-packages (from resemblyzer->-r requirements.txt (line 11)) (2.0.10)
# Requirement already satisfied: pycparser in c:\users\chakr\anaconda3\lib\site-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 7)) (2.21)
# Requirement already satisfied: setuptools in c:\users\chakr\anaconda3\lib\site-packages (from numba->face_alignment->-r requirements.txt (line 3)) (69.1.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\chakr\anaconda3\lib\site-packages (from numba->face_alignment->-r requirements.txt (line 3)) (0.38.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\chakr\anaconda3\lib\site-packages (from packaging>=20.0->librosa->-r requirements.txt (line 8)) (3.0.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\chakr\anaconda3\lib\site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.27.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\chakr\anaconda3\lib\site-packages (from pooch>=1.0->librosa->-r requirements.txt (line 8)) (4.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa->-r requirements.txt (line 8)) (2.0.4)
# Requirement already satisfied: fsspec in c:\users\chakr\anaconda3\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (2022.2.0)
# Requirement already satisfied: filelock in c:\users\chakr\anaconda3\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: sympy in c:\users\chakr\anaconda3\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\chakr\anaconda3\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chakr\anaconda3\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: networkx in c:\users\chakr\anaconda3\lib\site-packages (from torch->face_alignment->-r requirements.txt (line 3)) (2.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\chakr\anaconda3\lib\site-packages (from jinja2->torch->face_alignment->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\chakr\anaconda3\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\chakr\anaconda3\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (9.0.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\chakr\anaconda3\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\chakr\anaconda3\lib\site-packages (from scikit-image->face_alignment->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chakr\anaconda3\lib\site-packages (from sympy->torch->face_alignment->-r requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: colorama in c:\users\chakr\anaconda3\lib\site-packages (from tqdm->face_alignment->-r requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: tensorboardX in c:\users\chakr\anaconda3\lib\site-packages (2.6.2.2)
# Requirement already satisfied: packaging in c:\users\chakr\anaconda3\lib\site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in c:\users\chakr\anaconda3\lib\site-packages (from tensorboardX) (4.25.3)
# Requirement already satisfied: numpy in c:\users\chakr\anaconda3\lib\site-packages (from tensorboardX) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\chakr\anaconda3\lib\site-packages (from packaging->tensorboardX) (3.0.4)
# Requirement already satisfied: gdown in c:\users\chakr\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: requests[socks] in c:\users\chakr\anaconda3\lib\site-packages (from gdown) (2.27.1)
# Requirement already satisfied: tqdm in c:\users\chakr\anaconda3\lib\site-packages (from gdown) (4.64.0)
# Requirement already satisfied: filelock in c:\users\chakr\anaconda3\lib\site-packages (from gdown) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\chakr\anaconda3\lib\site-packages (from gdown) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chakr\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\lib\site-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Done!
# Download pre-trained models...
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chakr\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\chakr\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\chakr\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.4)
# Downloading...
# From (original): https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x
# From (redirected): https://drive.google.com/uc?id=1ZiwPp_h62LtjU0DwpelLUoodKPR85K7x&confirm=t&uuid=821a0f02-fc04-4818-b414-667bf5bcc4a9
# To: C:\Users\chakr\Downloads\makeittalk\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_autovc.pth
#
#   0%|          | 0.00/172M [00:00<?, ?B/s]
#   1%|          | 1.57M/172M [00:00<00:15, 11.3MB/s]
#   2%|1         | 3.15M/172M [00:00<00:17, 9.71MB/s]
#   3%|2         | 4.72M/172M [00:00<00:15, 10.5MB/s]
#   4%|3         | 6.29M/172M [00:00<00:13, 12.0MB/s]
#   5%|4         | 8.39M/172M [00:00<00:12, 13.6MB/s]
#   6%|5         | 9.96M/172M [00:00<00:12, 13.4MB/s]
#   7%|6         | 11.5M/172M [00:00<00:12, 13.0MB/s]
#   8%|7         | 13.1M/172M [00:01<00:11, 13.3MB/s]
#   9%|8         | 14.7M/172M [00:01<00:11, 13.1MB/s]
#  10%|9         | 16.8M/172M [00:01<00:10, 14.3MB/s]
#  11%|#         | 18.9M/172M [00:01<00:09, 15.7MB/s]
#  13%|#2        | 21.5M/172M [00:01<00:08, 18.0MB/s]
#  14%|#4        | 24.6M/172M [00:01<00:06, 21.5MB/s]
#  16%|#6        | 27.8M/172M [00:01<00:05, 24.1MB/s]
#  18%|#8        | 31.5M/172M [00:01<00:05, 26.7MB/s]
#  20%|##        | 34.6M/172M [00:01<00:05, 26.3MB/s]
#  22%|##1       | 37.7M/172M [00:02<00:04, 27.5MB/s]
#  24%|##3       | 40.9M/172M [00:02<00:04, 28.4MB/s]
#  26%|##5       | 44.0M/172M [00:02<00:04, 27.0MB/s]
#  27%|##7       | 47.2M/172M [00:02<00:05, 22.0MB/s]
#  29%|##8       | 49.8M/172M [00:02<00:05, 21.4MB/s]
#  31%|###1      | 53.5M/172M [00:02<00:04, 24.8MB/s]
#  33%|###2      | 56.6M/172M [00:02<00:04, 25.9MB/s]
#  35%|###4      | 59.8M/172M [00:02<00:04, 26.5MB/s]
#  38%|###7      | 64.5M/172M [00:03<00:03, 30.8MB/s]
#  40%|###9      | 68.2M/172M [00:03<00:03, 30.8MB/s]
#  42%|####1     | 71.8M/172M [00:03<00:03, 30.2MB/s]
#  44%|####3     | 75.0M/172M [00:03<00:03, 27.9MB/s]
#  45%|####5     | 78.1M/172M [00:03<00:03, 26.7MB/s]
#  47%|####7     | 81.3M/172M [00:03<00:03, 27.9MB/s]
#  49%|####9     | 84.4M/172M [00:03<00:03, 27.9MB/s]
#  51%|#####     | 87.6M/172M [00:04<00:04, 20.8MB/s]
#  52%|#####2    | 90.2M/172M [00:04<00:03, 20.6MB/s]
#  54%|#####4    | 93.3M/172M [00:04<00:03, 22.6MB/s]
#  56%|#####5    | 95.9M/172M [00:04<00:03, 19.8MB/s]
#  57%|#####7    | 98.6M/172M [00:04<00:03, 20.2MB/s]
#  59%|#####8    | 101M/172M [00:04<00:03, 20.1MB/s]
#  60%|######    | 104M/172M [00:04<00:03, 21.1MB/s]
#  62%|######1   | 106M/172M [00:05<00:04, 16.0MB/s]
#  63%|######3   | 109M/172M [00:05<00:03, 17.9MB/s]
#  65%|######4   | 112M/172M [00:05<00:03, 19.1MB/s]
#  66%|######6   | 114M/172M [00:05<00:02, 20.7MB/s]
#  69%|######8   | 118M/172M [00:05<00:02, 24.4MB/s]
#  70%|#######   | 121M/172M [00:05<00:02, 21.1MB/s]
#  73%|#######2  | 125M/172M [00:05<00:01, 25.1MB/s]
#  75%|#######5  | 129M/172M [00:05<00:01, 27.7MB/s]
#  77%|#######7  | 133M/172M [00:06<00:01, 29.8MB/s]
#  80%|#######9  | 137M/172M [00:06<00:01, 32.3MB/s]
#  82%|########1 | 141M/172M [00:06<00:01, 31.3MB/s]
#  84%|########3 | 144M/172M [00:06<00:00, 30.3MB/s]
#  86%|########5 | 147M/172M [00:06<00:01, 24.5MB/s]
#  88%|########7 | 150M/172M [00:06<00:01, 21.4MB/s]
#  89%|########9 | 154M/172M [00:06<00:00, 22.2MB/s]
#  92%|#########1| 158M/172M [00:07<00:00, 26.0MB/s]
#  94%|#########3| 161M/172M [00:07<00:00, 27.9MB/s]
#  96%|#########5| 165M/172M [00:07<00:00, 28.0MB/s]
#  98%|#########8| 169M/172M [00:07<00:00, 30.8MB/s]
# 100%|##########| 172M/172M [00:07<00:00, 23.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1r3bfEvTVl6pCNw5xwUhEglwDHjWtAqQp
# To: C:\Users\chakr\Downloads\makeittalk\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_content_branch.pth
#
#   0%|          | 0.00/7.88M [00:00<?, ?B/s]
#  47%|####6     | 3.67M/7.88M [00:00<00:00, 36.5MB/s]
# 100%|##########| 7.88M/7.88M [00:00<00:00, 39.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rV0jkyDqPW-aDJcj7xSO6Zt1zSXqn1mu
# To: C:\Users\chakr\Downloads\makeittalk\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_speaker_branch.pth
#
#   0%|          | 0.00/15.4M [00:00<?, ?B/s]
#   7%|6         | 1.05M/15.4M [00:00<00:03, 4.43MB/s]
#  14%|#3        | 2.10M/15.4M [00:00<00:01, 6.70MB/s]
#  20%|##        | 3.15M/15.4M [00:00<00:03, 3.94MB/s]
#  27%|##7       | 4.19M/15.4M [00:00<00:02, 5.01MB/s]
#  37%|###7      | 5.77M/15.4M [00:01<00:01, 6.28MB/s]
#  48%|####7     | 7.34M/15.4M [00:01<00:01, 7.79MB/s]
#  54%|#####4    | 8.39M/15.4M [00:01<00:00, 8.27MB/s]
#  61%|######1   | 9.44M/15.4M [00:01<00:00, 8.77MB/s]
#  71%|#######1  | 11.0M/15.4M [00:01<00:00, 10.3MB/s]
#  82%|########1 | 12.6M/15.4M [00:01<00:00, 9.94MB/s]
#  92%|#########1| 14.2M/15.4M [00:01<00:00, 7.82MB/s]
#  99%|#########8| 15.2M/15.4M [00:02<00:00, 7.57MB/s]
# 100%|##########| 15.4M/15.4M [00:02<00:00, 7.32MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a
# From (redirected): https://drive.google.com/uc?id=1i2LJXKp-yWKIEEgJ7C6cE3_2NirfY_0a&confirm=t&uuid=79294774-e3d0-4c94-b041-7221aea149cf
# To: C:\Users\chakr\Downloads\makeittalk\MakeItTalk\MakeItTalk\examples\ckpt\ckpt_116_i2i_comb.pth
#
#   0%|          | 0.00/839M [00:00<?, ?B/s]
#   0%|          | 524k/839M [00:00<02:42, 5.15MB/s]
#   0%|          | 1.57M/839M [00:00<02:21, 5.91MB/s]
#   0%|          | 2.62M/839M [00:00<02:23, 5.84MB/s]
#   0%|          | 3.67M/839M [00:00<02:16, 6.12MB/s]
#   1%|          | 5.24M/839M [00:00<01:56, 7.13MB/s]
#   1%|          | 6.29M/839M [00:01<02:31, 5.50MB/s]
#   1%|          | 7.34M/839M [00:01<02:10, 6.35MB/s]
#   1%|1         | 8.39M/839M [00:01<02:15, 6.12MB/s]
#   1%|1         | 9.44M/839M [00:01<02:21, 5.85MB/s]
#   1%|1         | 10.5M/839M [00:01<02:09, 6.38MB/s]
#   1%|1         | 11.5M/839M [00:01<02:13, 6.17MB/s]
#   2%|1         | 12.6M/839M [00:02<02:08, 6.42MB/s]
#   2%|1         | 13.6M/839M [00:02<02:03, 6.67MB/s]
#   2%|1         | 14.7M/839M [00:02<02:08, 6.43MB/s]
#   2%|1         | 15.7M/839M [00:02<02:14, 6.13MB/s]
#   2%|2         | 16.8M/839M [00:02<02:05, 6.56MB/s]
#   2%|2         | 17.8M/839M [00:02<02:06, 6.49MB/s]
#   2%|2         | 18.9M/839M [00:02<01:54, 7.17MB/s]
#   2%|2         | 19.9M/839M [00:03<02:00, 6.79MB/s]
#   3%|2         | 21.0M/839M [00:03<01:49, 7.44MB/s]
#   3%|2         | 22.0M/839M [00:03<01:49, 7.47MB/s]
#   3%|2         | 23.1M/839M [00:03<01:42, 7.98MB/s]
#   3%|2         | 24.1M/839M [00:03<01:43, 7.85MB/s]
#   3%|3         | 25.7M/839M [00:03<01:27, 9.28MB/s]
#   3%|3         | 26.7M/839M [00:03<01:30, 8.97MB/s]
#   3%|3         | 27.8M/839M [00:04<01:43, 7.85MB/s]
#   3%|3         | 28.8M/839M [00:04<01:40, 8.07MB/s]
#   4%|3         | 30.4M/839M [00:04<01:29, 8.98MB/s]
#   4%|3         | 32.0M/839M [00:04<01:26, 9.36MB/s]
#   4%|4         | 33.6M/839M [00:04<01:25, 9.46MB/s]
#   4%|4         | 35.1M/839M [00:04<01:16, 10.5MB/s]
#   4%|4         | 36.7M/839M [00:04<01:15, 10.6MB/s]
#   5%|4         | 38.3M/839M [00:05<01:18, 10.2MB/s]
#   5%|4         | 39.3M/839M [00:05<01:40, 7.96MB/s]
#   5%|4         | 40.4M/839M [00:05<01:43, 7.71MB/s]
#   5%|4         | 41.4M/839M [00:05<01:40, 7.93MB/s]
#   5%|5         | 42.5M/839M [00:05<01:37, 8.17MB/s]
#   5%|5         | 43.5M/839M [00:05<01:41, 7.81MB/s]
#   5%|5         | 44.6M/839M [00:05<01:43, 7.68MB/s]
#   6%|5         | 46.1M/839M [00:06<01:36, 8.20MB/s]
#   6%|5         | 47.7M/839M [00:06<01:31, 8.67MB/s]
#   6%|5         | 48.8M/839M [00:06<01:34, 8.34MB/s]
#   6%|5         | 49.8M/839M [00:06<01:35, 8.28MB/s]
#   6%|6         | 50.9M/839M [00:06<01:35, 8.29MB/s]
#   6%|6         | 51.9M/839M [00:06<01:32, 8.48MB/s]
#   6%|6         | 53.5M/839M [00:06<01:26, 9.04MB/s]
#   7%|6         | 55.1M/839M [00:07<01:18, 10.0MB/s]
#   7%|6         | 56.1M/839M [00:07<01:18, 9.96MB/s]
#   7%|6         | 57.7M/839M [00:07<01:13, 10.6MB/s]
#   7%|7         | 59.2M/839M [00:07<01:09, 11.2MB/s]
#   7%|7         | 60.8M/839M [00:07<01:05, 11.9MB/s]
#   7%|7         | 62.4M/839M [00:07<01:04, 12.1MB/s]
#   8%|7         | 64.0M/839M [00:07<01:06, 11.7MB/s]
#   8%|7         | 65.5M/839M [00:08<01:18, 9.87MB/s]
#   8%|8         | 67.1M/839M [00:08<01:12, 10.7MB/s]
#   8%|8         | 68.7M/839M [00:08<01:09, 11.0MB/s]
#   8%|8         | 70.3M/839M [00:08<01:11, 10.7MB/s]
#   9%|8         | 71.8M/839M [00:08<01:10, 10.8MB/s]
#   9%|8         | 73.4M/839M [00:08<01:09, 11.0MB/s]
#   9%|8         | 75.0M/839M [00:08<01:05, 11.6MB/s]
#   9%|9         | 76.5M/839M [00:09<01:07, 11.3MB/s]
#   9%|9         | 78.1M/839M [00:09<01:05, 11.6MB/s]
#  10%|9         | 79.7M/839M [00:09<01:04, 11.8MB/s]
#  10%|9         | 81.3M/839M [00:09<01:12, 10.4MB/s]
#  10%|9         | 82.8M/839M [00:09<01:12, 10.4MB/s]
#  97%|#########6| 813M/839M [00:39<00:01, 23.1MB/s]
#  97%|#########7| 815M/839M [00:39<00:00, 23.8MB/s]
#  98%|#########7| 818M/839M [00:39<00:00, 24.5MB/s]
#  98%|#########7| 821M/839M [00:39<00:00, 23.4MB/s]
#  98%|#########8| 824M/839M [00:39<00:00, 23.2MB/s]
#  99%|#########8| 826M/839M [00:40<00:00, 22.2MB/s]
#  99%|#########8| 829M/839M [00:40<00:00, 24.3MB/s]
#  99%|#########9| 833M/839M [00:40<00:00, 24.8MB/s]
# 100%|#########9| 836M/839M [00:40<00:00, 27.6MB/s]
# 100%|##########| 839M/839M [00:40<00:00, 20.7MB/s]
# Done!
# Downloading...
# From: https://drive.google.com/uc?id=18-0CYl5E6ungS3H4rRSHjfYvvm-WwjTI
# To: C:\Users\chakr\Downloads\makeittalk\MakeItTalk\MakeItTalk\examples\dump\emb.pickle
#
#   0%|          | 0.00/30.9M [00:00<?, ?B/s]
#   7%|6         | 2.10M/30.9M [00:00<00:01, 18.7MB/s]
#  17%|#6        | 5.24M/30.9M [00:00<00:01, 22.6MB/s]
#  31%|###       | 9.44M/30.9M [00:00<00:00, 29.3MB/s]
#  42%|####2     | 13.1M/30.9M [00:00<00:00, 30.4MB/s]
#  54%|#####4    | 16.8M/30.9M [00:00<00:00, 31.7MB/s]
#  66%|######6   | 20.4M/30.9M [00:00<00:00, 29.5MB/s]
#  80%|#######9  | 24.6M/30.9M [00:00<00:00, 30.3MB/s]
#  90%|########9 | 27.8M/30.9M [00:00<00:00, 28.9MB/s]
# 100%|##########| 30.9M/30.9M [00:01<00:00, 29.4MB/s]

# %% [markdown]
# ## Animate your photos here!
#
# - Upload your images to `examples` with size `256x256`. Or use existing ones.
#
# - Upload your speech audio files (could be many) to `examples`. Since it will process all `.wav` files under `examples`, remember to delete non-necessary `.wav` files. Or use an existing one `M6_04_16k.wav`.

# %% [markdown]
# ## Step 1/3: Choose your image (in below Dropdown).

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\chakr\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\chakr\anaconda3\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipywidgets) (8.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\chakr\anaconda3\lib\site-packages (from ipywidgets) (6.9.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\chakr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\chakr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: decorator in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: backcall in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (69.1.0)
# Requirement already satisfied: pickleshare in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: colorama in c:\users\chakr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\chakr\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\chakr\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\chakr\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\chakr\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\chakr\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (302)
# Requirement already satisfied: fastjsonschema in c:\users\chakr\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\chakr\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\chakr\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\chakr\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\chakr\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\chakr\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\chakr\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\chakr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.4)
# Requirement already satisfied: jinja2 in c:\users\chakr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\chakr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\chakr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\chakr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\chakr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\chakr\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\chakr\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\chakr\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\chakr\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\chakr\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.11.1)
# Requirement already satisfied: testpath in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: bleach in c:\users\chakr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chakr\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\chakr\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in c:\users\chakr\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\chakr\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.4)
# Requirement already satisfied: asttokens in c:\users\chakr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in c:\users\chakr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\chakr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)

# %%
import ipywidgets as widgets
import glob
import matplotlib.pyplot as plt
print("Choose the image name to animate: (saved in folder 'examples/')")
img_list = glob.glob1('examples', '*.jpg')
img_list.sort()
img_list = [item.split('.')[0] for item in img_list]
img_list.append('paul')
print("Available image options:", img_list)
default_head_name = widgets.Dropdown(options=img_list, value='paul')
def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        plt.imshow(plt.imread('examples/{}.jpg'.format(default_head_name.value)))
        plt.axis('off')
        plt.show()
default_head_name.observe(on_change)
display(default_head_name)
print(default_head_name.value)
plt.imshow(plt.imread('examples/{}.jpg'.format(default_head_name.value)))
plt.axis('off')
plt.show()
# Out:
# Choose the image name to animate: (saved in folder 'examples/')
# Available image options: ['angelina', 'anne', 'anne2', 'audrey', 'aya', 'captain', 'captain2', 'cesi', 'chris', 'chris2', 'dali', 'donald', 'dragonmom', 'dwayne', 'dwayne2', 'dwayne3', 'harry', 'hermione', 'hermione2', 'hound', 'jali', 'john', 'johncartoon', 'johnny', 'kalo', 'lab1', 'lab2', 'lab3', 'lab4', 'leo', 'leo2', 'monalisa2', 'monalisa3', 'morgan', 'mulan', 'natalie', 'natalie2', 'neo', 'obama', 'paint1', 'paint3', 'paint_boy', 'paint_boy2', 'paul', 'rihanna', 'ron', 'scarlett', 'statue1', 'statue2', 'stephen', 'taylor', 'trump', 'trump2', 'paul']
# Dropdown(index=43, options=('angelina', 'anne', 'anne2', 'audrey', 'aya', 'captain', 'captain2', 'cesi', 'chri…
# paul

# %% [markdown]
# ## Step 2/3: Setup your animation controllers (on right Sliders).

# %%
import matplotlib.pyplot as plt

# Choose the image name directly
image_name = "paul"

# Load and display the chosen image
img_path = 'examples/{}.jpg'.format(image_name)
img = plt.imread(img_path)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#@markdown # Animation Controllers
#@markdown Amplify the lip motion in horizontal direction
AMP_LIP_SHAPE_X = 2 #@param {type:"slider", min:0.5, max:5.0, step:0.1}

#@markdown Amplify the lip motion in vertical direction
AMP_LIP_SHAPE_Y = 2 #@param {type:"slider", min:0.5, max:5.0, step:0.1}

#@markdown Amplify the head pose motion (usually smaller than 1.0, put it to 0. for a static head pose)
AMP_HEAD_POSE_MOTION = 0.35 #@param {type:"slider", min:0.0, max:1.0, step:0.05}

#@markdown Add naive eye blink
ADD_NAIVE_EYE = True  #@param ["False", "True"] {type:"raw"}

#@markdown If your image has an opened mouth, put this as True, else False
CLOSE_INPUT_FACE_MOUTH = False  #@param ["False", "True"] {type:"raw"}          


#@markdown # Landmark Adjustment

#@markdown Adjust upper lip thickness (postive value means thicker)
UPPER_LIP_ADJUST = -1 #@param {type:"slider", min:-3.0, max:3.0, step:1.0}

#@markdown Adjust lower lip thickness (postive value means thicker)
LOWER_LIP_ADJUST = -1 #@param {type:"slider", min:-3.0, max:3.0, step:1.0}

#@markdown Adjust static lip width (in multipication)
LIP_WIDTH_ADJUST = 1.0 #@param {type:"slider", min:0.8, max:1.2, step:0.01}

# %% [markdown]
# ## Step 3/3: One-click to Run (just wait in seconds).

# %%
# !pip uninstall librosa --yes
# !pip install librosa==0.9.1
# Out:
# Found existing installation: librosa 0.9.1
# Uninstalling librosa-0.9.1:
#   Successfully uninstalled librosa-0.9.1
# Collecting librosa==0.9.1
#   Using cached librosa-0.9.1-py3-none-any.whl (213 kB)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (3.0.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (0.4.3)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (1.21.5)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (0.12.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (1.0.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (1.8.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (21.3)
# Requirement already satisfied: joblib>=0.14 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (1.1.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (1.8.1)
# Requirement already satisfied: numba>=0.45.1 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (0.55.1)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\chakr\anaconda3\lib\site-packages (from librosa==0.9.1) (5.1.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\chakr\anaconda3\lib\site-packages (from numba>=0.45.1->librosa==0.9.1) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\chakr\anaconda3\lib\site-packages (from numba>=0.45.1->librosa==0.9.1) (69.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\chakr\anaconda3\lib\site-packages (from packaging>=20.0->librosa==0.9.1) (3.0.4)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\chakr\anaconda3\lib\site-packages (from pooch>=1.0->librosa==0.9.1) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\chakr\anaconda3\lib\site-packages (from pooch>=1.0->librosa==0.9.1) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1) (1.26.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa==0.9.1) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\chakr\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa==0.9.1) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\chakr\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1) (2.21)
# Installing collected packages: librosa
# Successfully installed librosa-0.9.1

# %%
# !pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch==2.2.1 in c:\users\chakr\anaconda3\lib\site-packages (2.2.1+cu121)
# Requirement already satisfied: torchvision==0.17.1 in c:\users\chakr\anaconda3\lib\site-packages (0.17.1+cu121)
# Requirement already satisfied: torchaudio==2.2.1 in c:\users\chakr\anaconda3\lib\site-packages (2.2.1+cu121)
# Requirement already satisfied: sympy in c:\users\chakr\anaconda3\lib\site-packages (from torch==2.2.1) (1.10.1)
# Requirement already satisfied: networkx in c:\users\chakr\anaconda3\lib\site-packages (from torch==2.2.1) (2.7.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chakr\anaconda3\lib\site-packages (from torch==2.2.1) (4.9.0)
# Requirement already satisfied: filelock in c:\users\chakr\anaconda3\lib\site-packages (from torch==2.2.1) (3.6.0)
# Requirement already satisfied: fsspec in c:\users\chakr\anaconda3\lib\site-packages (from torch==2.2.1) (2022.2.0)
# Requirement already satisfied: jinja2 in c:\users\chakr\anaconda3\lib\site-packages (from torch==2.2.1) (2.11.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\chakr\anaconda3\lib\site-packages (from torchvision==0.17.1) (9.0.1)
# Requirement already satisfied: numpy in c:\users\chakr\anaconda3\lib\site-packages (from torchvision==0.17.1) (1.21.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\chakr\anaconda3\lib\site-packages (from jinja2->torch==2.2.1) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chakr\anaconda3\lib\site-packages (from sympy->torch==2.2.1) (1.2.1)

# %%
import os
print(os.path.abspath('examples/dump/random_val_fl.pickle'))
# Out:
# C:\Users\chakr\Downloads\makeittalk\MakeItTalk\MakeItTalk\examples\dump\random_val_fl.pickle

# %%
import sys
sys.path.append("thirdparty/AdaptiveWingLoss")
import os, glob
import numpy as np
import cv2
import argparse
from src.approaches.train_image_translation import Image_translation_block
import torch
import pickle
import face_alignment
from src.autovc.AutoVC_mel_Convertor_retrain_version import AutoVC_mel_Convertor
import shutil
import time
import util.utils as util
from scipy.signal import savgol_filter
from src.approaches.train_audio2landmark import Audio2landmark_model

sys.stdout = open(os.devnull, 'a')

parser = argparse.ArgumentParser()
parser.add_argument('--jpg', type=str, default='{}.jpg'.format(default_head_name.value))
parser.add_argument('--close_input_face_mouth', default=CLOSE_INPUT_FACE_MOUTH, action='store_true')
parser.add_argument('--load_AUTOVC_name', type=str, default='examples/ckpt/ckpt_autovc.pth')
parser.add_argument('--load_a2l_G_name', type=str, default='examples/ckpt/ckpt_speaker_branch.pth')
parser.add_argument('--load_a2l_C_name', type=str, default='examples/ckpt/ckpt_content_branch.pth') #ckpt_audio2landmark_c.pth')
parser.add_argument('--load_G_name', type=str, default='examples/ckpt/ckpt_116_i2i_comb.pth') #ckpt_image2image.pth') #ckpt_i2i_finetune_150.pth') #c
parser.add_argument('--amp_lip_x', type=float, default=AMP_LIP_SHAPE_X)
parser.add_argument('--amp_lip_y', type=float, default=AMP_LIP_SHAPE_Y)
parser.add_argument('--amp_pos', type=float, default=AMP_HEAD_POSE_MOTION)
parser.add_argument('--reuse_train_emb_list', type=str, nargs='+', default=[]) #  ['iWeklsXc0H8']) #['45hn7-LXDX8']) #['E_kmpT-EfOg']) #'iWeklsXc0H8', '29k8RtSUjE0', '45hn7-LXDX8',
parser.add_argument('--add_audio_in', default=False, action='store_true')
parser.add_argument('--comb_fan_awing', default=False, action='store_true')
parser.add_argument('--output_folder', type=str, default='examples')
parser.add_argument('--test_end2end', default=True, action='store_true')
parser.add_argument('--dump_dir', type=str, default='', help='')
parser.add_argument('--pos_dim', default=7, type=int)
parser.add_argument('--use_prior_net', default=True, action='store_true')
parser.add_argument('--transformer_d_model', default=32, type=int)
parser.add_argument('--transformer_N', default=2, type=int)
parser.add_argument('--transformer_heads', default=2, type=int)
parser.add_argument('--spk_emb_enc_size', default=16, type=int)
parser.add_argument('--init_content_encoder', type=str, default='')
parser.add_argument('--lr', type=float, default=1e-3, help='learning rate')
parser.add_argument('--reg_lr', type=float, default=1e-6, help='weight decay')
parser.add_argument('--write', default=False, action='store_true')
parser.add_argument('--segment_batch_size', type=int, default=1, help='batch size')
parser.add_argument('--emb_coef', default=3.0, type=float)
parser.add_argument('--lambda_laplacian_smooth_loss', default=1.0, type=float)
parser.add_argument('--use_11spk_only', default=False, action='store_true')
parser.add_argument('-f')
opt_parser = parser.parse_args()

img = cv2.imread('examples/' + opt_parser.jpg)
predictor = face_alignment.FaceAlignment(face_alignment.LandmarksType.THREE_D, device='cpu', flip_input=True)
shapes = predictor.get_landmarks(img)
if (not shapes or len(shapes) != 1):
    print('Cannot detect face landmarks. Exit.')
    exit(-1)
shape_3d = shapes[0]
if(opt_parser.close_input_face_mouth):
    util.close_input_face_mouth(shape_3d)
shape_3d[48:, 0] = (shape_3d[48:, 0] - np.mean(shape_3d[48:, 0])) * LIP_WIDTH_ADJUST + np.mean(shape_3d[48:, 0]) # wider lips
shape_3d[49:54, 1] -= UPPER_LIP_ADJUST           # thinner upper lip
shape_3d[55:60, 1] += LOWER_LIP_ADJUST           # thinner lower lip
shape_3d[[37,38,43,44], 1] -=2.    # larger eyes
shape_3d[[40,41,46,47], 1] +=2.    # larger eyes
shape_3d, scale, shift = util.norm_input_face(shape_3d)

print("Loaded Image...", file=sys.stderr)

au_data = []
au_emb = []
ains = glob.glob1('examples', 'nplataoplomo.wav')
ains = [item for item in ains if item != 'tmp.wav']
ains.sort()
for ain in ains:
    os.system('ffmpeg -y -loglevel error -i examples/{} -ar 16000 examples/tmp.wav'.format(ain))
    shutil.copyfile('examples/tmp.wav', 'examples/{}'.format(ain))

    # au embedding
    from thirdparty.resemblyer_util.speaker_emb import get_spk_emb
    me, ae = get_spk_emb('examples/{}'.format(ain))
    au_emb.append(me.reshape(-1))

    print('Processing audio file', ain)
    c = AutoVC_mel_Convertor('examples')

    au_data_i = c.convert_single_wav_to_autovc_input(audio_filename=os.path.join('examples', ain),
           autovc_model_path=opt_parser.load_AUTOVC_name)
    au_data += au_data_i
if(os.path.isfile('examples/tmp.wav')):
    os.remove('examples/tmp.wav')

print("Loaded audio...", file=sys.stderr)

# landmark fake placeholder
fl_data = []
rot_tran, rot_quat, anchor_t_shape = [], [], []
for au, info in au_data:
    au_length = au.shape[0]
    fl = np.zeros(shape=(au_length, 68 * 3))
    fl_data.append((fl, info))
    rot_tran.append(np.zeros(shape=(au_length, 3, 4)))
    rot_quat.append(np.zeros(shape=(au_length, 4)))
    anchor_t_shape.append(np.zeros(shape=(au_length, 68 * 3)))

if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_fl_interp.pickle'))
if(os.path.exists(os.path.join('examples', 'dump', 'random_val_au.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_au.pickle'))
if (os.path.exists(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))):
    os.remove(os.path.join('examples', 'dump', 'random_val_gaze.pickle'))

with open(os.path.join('examples', 'dump', 'random_val_fl.pickle'), 'wb') as fp:
    pickle.dump(fl_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_au.pickle'), 'wb') as fp:
    pickle.dump(au_data, fp)
with open(os.path.join('examples', 'dump', 'random_val_gaze.pickle'), 'wb') as fp:
    gaze = {'rot_trans':rot_tran, 'rot_quat':rot_quat, 'anchor_t_shape':anchor_t_shape}
    pickle.dump(gaze, fp)

model = Audio2landmark_model(opt_parser, jpg_shape=shape_3d)
if(len(opt_parser.reuse_train_emb_list) == 0):
    model.test(au_emb=au_emb)
else:
    model.test(au_emb=None)

print("Audio->Landmark...", file=sys.stderr)

fls = glob.glob1('examples', 'pred_fls_*.txt')
fls.sort()

for i in range(0,len(fls)):
    fl = np.loadtxt(os.path.join('examples', fls[i])).reshape((-1, 68,3))
    fl[:, :, 0:2] = -fl[:, :, 0:2]
    fl[:, :, 0:2] = fl[:, :, 0:2] / scale - shift

    if (ADD_NAIVE_EYE):
        fl = util.add_naive_eye(fl)

    # additional smooth
    fl = fl.reshape((-1, 204))
    fl[:, :48 * 3] = savgol_filter(fl[:, :48 * 3], 15, 3, axis=0)
    fl[:, 48*3:] = savgol_filter(fl[:, 48*3:], 5, 3, axis=0)
    fl = fl.reshape((-1, 68, 3))

    ''' STEP 6: Imag2image translation '''
    model = Image_translation_block(opt_parser, single_test=True)
    with torch.no_grad():
        model.single_test(jpg=img, fls=fl, filename=fls[i], prefix=opt_parser.jpg.split('.')[0])
        print('finish image2image gen')
    os.remove(os.path.join('examples', fls[i]))

    print("{} / {}: Landmark->Face...".format(i+1, len(fls)), file=sys.stderr)
print("Done!", file=sys.stderr)
# Out:
# Loaded Image...
# C:\Users\chakr\Downloads\makeittalk\MakeItTalk\src\autovc\retrain_version\vocoder_spec\extract_f0_func.py:97: FutureWarning: Pass sr=16000, n_fft=1024 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_basis = mel(16000, 1024, fmin=90, fmax=7600, n_mels=80).T
# Loaded audio...
# C:\Users\chakr\Downloads\makeittalk\MakeItTalk\src\approaches\train_audio2landmark.py:98: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   z = torch.tensor(torch.zeros(aus.shape[0], 128), requires_grad=False, dtype=torch.float).to(device)
# Audio->Landmark...
# 1 / 1: Landmark->Face...
# Done!

# %% [markdown]
# ## Visualize your animation!

# %%
from IPython.display import HTML
from base64 import b64encode

for ain in ains:
  OUTPUT_MP4_NAME = '{}_pred_fls_{}_audio_embed.mp4'.format(
    opt_parser.jpg.split('.')[0],
    ain.split('.')[0]
    )
  mp4 = open('examples/{}'.format(OUTPUT_MP4_NAME),'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

  print('Display animation: examples/{}'.format(OUTPUT_MP4_NAME), file=sys.stderr)
  display(HTML("""
  <video width=600 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
# Out:
# Display animation: examples/paul_pred_fls_nplataoplomo_audio_embed.mp4
#   <video width=600 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>
